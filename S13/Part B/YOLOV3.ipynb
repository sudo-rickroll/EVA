# %%
from google.colab import drive
drive.mount('gdrive')
# Out:
# Mounted at gdrive

# %%
# %cd /content/gdrive/MyDrive/EVA S9/EVA/S13
# Out:
# /content/gdrive/MyDrive/EVA S9/EVA/S13

# %%
from IPython.display import Image

# %%
# !git clone https://github.com/theschoolofai/YoloV3.git

# %%
# %cd ./YoloV3
# Out:
# /content/gdrive/MyDrive/EVA S9/EVA/S13/YoloV3

# %%
# !mkdir 'weights'

# %%
# %ls
# Out:
#  annotation_tool/   __pycache__/   test_batch0.png    utils/
#  cfg/               README.md      test.py            vim.exe.stackdump
#  data/              results.json   ting               weights/
#  detect.py          results.png    train_batch0.png
#  models.py          results.txt    train.py
#  output/            runs/         'ubdivisions=1'

# %%
# !python train.py --data data/assignment13/custom.data --batch 10 --cache --cfg cfg/yolov3-custom.cfg --epochs 3 --nosave
# Out:
# Namespace(accumulate=4, adam=False, batch_size=10, bucket='', cache_images=True, cfg='cfg/yolov3-custom.cfg', data='data/assignment13/custom.data', device='', epochs=3, evolve=False, img_size=[512], multi_scale=False, name='', nosave=True, notest=False, rect=False, resume=False, single_cls=False, weights='weights/yolov3-spp-ultralytics.pt')
# Using CUDA device0 _CudaDeviceProperties(name='Tesla T4', total_memory=15109MB)
#
# 2021-03-20 08:36:19.896291: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# Run 'tensorboard --logdir=runs' to view tensorboard at http://localhost:6006/
# WARNING: smart bias initialization failure.
# WARNING: smart bias initialization failure.
# WARNING: smart bias initialization failure.
# Model Summary: 225 layers, 6.25895e+07 parameters, 6.25895e+07 gradients
# Caching labels (3034 found, 131 missing, 38 empty, 0 duplicate, for 3203 images): 100% 3203/3203 [14:46<00:00,  3.61it/s]
# ...

# %%
# !python detect.py --conf-thres 0.3 --output "output"
# Out:
# Namespace(agnostic_nms=False, augment=False, cfg='cfg/yolov3-custom.cfg', classes=None, conf_thres=0.3, device='', fourcc='mp4v', half=False, img_size=512, iou_thres=0.6, names='data/customdata/custom.names', output='output', save_txt=False, source='data/customdata/images', view_img=False, weights='weights/last.pt')
# Using CUDA device0 _CudaDeviceProperties(name='Tesla T4', total_memory=15109MB)
#
# Model Summary: 225 layers, 6.25895e+07 parameters, 6.25895e+07 gradients
# image 1/288 data/customdata/images/image-001.jpg: 320x512 Done. (0.033s)
# image 2/288 data/customdata/images/image-002.jpg: 320x512 Done. (0.033s)
# image 3/288 data/customdata/images/image-003.jpg: 320x512 Done. (0.033s)
# image 4/288 data/customdata/images/image-004.jpg: 320x512 Done. (0.033s)
# image 5/288 data/customdata/images/image-005.jpg: 320x512 Done. (0.033s)
# image 6/288 data/customdata/images/image-006.jpg: 320x512 Done. (0.033s)
# ...

# %%
Image(filename='/content/gdrive/MyDrive/EVA S9/EVA/S13/YoloV3/output/image-277.jpg', width=600)
