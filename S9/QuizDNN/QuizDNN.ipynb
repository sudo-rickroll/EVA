# %% [markdown]
# ##Importing the required modules

# %%
from google.colab import  drive
drive.mount('./gdrive')
# %cd '/content/gdrive/MyDrive/EVA S9/EVA/S9/QuizDNN'
# Out:
# Mounted at ./gdrive
# /content/gdrive/MyDrive/EVA S9/EVA/S9

# %%
from datetime import datetime 
import torch
import torchvision
import torchvision.transforms as transforms
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import matplotlib.pyplot as plt
import numpy as np
from torch.optim.lr_scheduler import StepLR

# %%
print("Current Date/Time: ", datetime.now())
# Out:
# Current Date/Time:  2021-02-06 17:50:15.037783

# %%
from utils import DataProcessing
from regularizations import Regularizations
from model import *
from graphs import Graphs
from train import *
from test import *
from QuizDNN import DNN

# %% [markdown]
# ## Maintaining Reproducability

# %%
torch.manual_seed(1)
torch.backends.cudnn.deterministic = True

# %% [markdown]
# ##Loading the Dataset, performing image transformations and loading the DataLoader

# %%
data = DataProcessing('CIFAR10')

# %%
train_set = data.Dataset('./Data', True, True, transforms.ToTensor())
test_set = data.Dataset('./Data', False, True, transforms.ToTensor())
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
train_set.classes
# Out:
# ['airplane',
#  'automobile',
#  'bird',
#  'cat',
#  'deer',
#  'dog',
#  'frog',
#  'horse',
#  'ship',
#  'truck']

# %%
data.Transform(train_set, transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5)), transforms.RandomHorizontalFlip())
data.Transform(test_set, transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5)), transforms.RandomHorizontalFlip())

# %%
train_loader = data.DataLoader(train_set, 100, shuffle=True, num_workers=4, pin_memory=True)
test_loader = data.DataLoader(test_set, 100, shuffle=True, num_workers=4, pin_memory=True)

# %% [markdown]
# ## Taking a sneak peek at the dataset

# %%
batch = next(iter(train_loader))
images, labels = batch
image, label = [], []
for index in range(10):
  image.append(images[index])
  label.append(train_set.classes[labels[index].item()])
grid = torchvision.utils.make_grid(image, nrow=5)
plt.imshow(np.transpose(grid/2 + 0.5,(1,2,0)))
plt.axis('off')
plt.show()
print(label)
# Out:
# ['frog', 'ship', 'airplane', 'truck', 'truck', 'airplane', 'ship', 'horse', 'deer', 'dog']

# %% [markdown]
# ## Viewing the parameter count used in the model

# %%
# !pip install torchsummary
from torchsummary import summary
use_cuda = torch.cuda.is_available() # check if GPU available
device = torch.device("cuda" if use_cuda else "cpu") # use cpu if gpu is not available
model = DNN().to(device) 
summary(model, input_size=(3,32,32))
# Out:
# Requirement already satisfied: torchsummary in /usr/local/lib/python3.6/dist-packages (1.5.1)
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 64, 32, 32]           1,728
#               ReLU-2           [-1, 64, 32, 32]               0
#        BatchNorm2d-3           [-1, 64, 32, 32]             128
#            Dropout-4           [-1, 64, 32, 32]               0
#             Conv2d-5           [-1, 64, 32, 32]          36,864
#               ReLU-6           [-1, 64, 32, 32]               0
#        BatchNorm2d-7           [-1, 64, 32, 32]             128
#            Dropout-8           [-1, 64, 32, 32]               0
#             Conv2d-9           [-1, 64, 32, 32]          36,864
#              ReLU-10           [-1, 64, 32, 32]               0
#       BatchNorm2d-11           [-1, 64, 32, 32]             128
#           Dropout-12           [-1, 64, 32, 32]               0
#         MaxPool2d-13           [-1, 64, 16, 16]               0
#            Conv2d-14           [-1, 64, 16, 16]          36,864
#              ReLU-15           [-1, 64, 16, 16]               0
#       BatchNorm2d-16           [-1, 64, 16, 16]             128
#           Dropout-17           [-1, 64, 16, 16]               0
#            Conv2d-18           [-1, 64, 16, 16]          36,864
#              ReLU-19           [-1, 64, 16, 16]               0
#       BatchNorm2d-20           [-1, 64, 16, 16]             128
#           Dropout-21           [-1, 64, 16, 16]               0
#            Conv2d-22           [-1, 64, 16, 16]          36,864
#              ReLU-23           [-1, 64, 16, 16]               0
#       BatchNorm2d-24           [-1, 64, 16, 16]             128
#           Dropout-25           [-1, 64, 16, 16]               0
#         MaxPool2d-26             [-1, 64, 8, 8]               0
#            Conv2d-27             [-1, 64, 8, 8]          36,864
#              ReLU-28             [-1, 64, 8, 8]               0
#       BatchNorm2d-29             [-1, 64, 8, 8]             128
#           Dropout-30             [-1, 64, 8, 8]               0
#            Conv2d-31             [-1, 64, 8, 8]          36,864
#              ReLU-32             [-1, 64, 8, 8]               0
#       BatchNorm2d-33             [-1, 64, 8, 8]             128
#           Dropout-34             [-1, 64, 8, 8]               0
#            Conv2d-35             [-1, 64, 8, 8]          36,864
#              ReLU-36             [-1, 64, 8, 8]               0
#       BatchNorm2d-37             [-1, 64, 8, 8]             128
#           Dropout-38             [-1, 64, 8, 8]               0
# AdaptiveAvgPool2d-39             [-1, 64, 1, 1]               0
#            Linear-40                   [-1, 10]             650
# ================================================================
# Total params: 298,442
# Trainable params: 298,442
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.01
# Forward/backward pass size (MB): 8.03
# Params size (MB): 1.14
# Estimated Total Size (MB): 9.18
# ----------------------------------------------------------------

# %% [markdown]
# ##Loading the object for different regularizations

# %%
regularizer = Regularizations('SGD', model, 0.01, 0.9, 6, 0.1)

# %% [markdown]
# ## Defining the main sequence of training and testing the model using the imported modules

# %%
def run(epochs, model, device, train_loader, regularizer, test_set, test_loader):
  train_losses, train_accuracies, test_losses, test_accuracies = [], [], [], []
  wrong_pred_data={'Images':[], 'Predicted':[], 'Actual':[]}
  last_epoch = False
  for epoch in range(epochs):
    print(f"Epoch {epoch+1} in progress....")
    train_loss, train_accuracy = train_model(model, device, train_loader, regularizer)
    if epoch == epochs - 1:
      last_epoch = True        
    test_loss, test_accuracy = test_model(model, device, test_set, test_loader, regularizer, wrong_pred_data['Predicted'], wrong_pred_data['Actual'], wrong_pred_data['Images'], last_epoch)
    print(f"\nEpoch : {epoch+1} \n\nAverage Train Loss : {train_loss :.9f} \nTrain Accuracy : {train_accuracy : .4f}% \n\nAverage Test Loss : {test_loss :.9f} \nTest Accuracy : {test_accuracy : .4f}% \n\n")
    train_losses.append(train_loss)
    train_accuracies.append(train_accuracy)
    test_losses.append(test_loss)
    test_accuracies.append(test_accuracy)
    regularizer.optimizer_step(step=True)
  return train_losses, train_accuracies, test_losses, test_accuracies, wrong_pred_data

# %% [markdown]
# ## Logging the results

# %%
train_losses, train_accuracies, test_losses, test_accuracies, wrong_pred_data = run(25, model, device, train_loader, regularizer, test_set, test_loader)
# Out:
# Epoch 1 in progress....
#
# Epoch : 1
#
# Average Train Loss : 0.013379295
# Train Accuracy :  51.3260%
#
# Average Test Loss : 0.010804065
# Test Accuracy :  61.5600%
#
#
# Epoch 2 in progress....
#
# Epoch : 2
#
# Average Train Loss : 0.009225017
# Train Accuracy :  67.4040%
#
# Average Test Loss : 0.009358495
# Test Accuracy :  66.9900%
#
#
# Epoch 3 in progress....
#
# Epoch : 3
#
# Average Train Loss : 0.007507210
# Train Accuracy :  73.7580%
#
# Average Test Loss : 0.007515606
# Test Accuracy :  73.4700%
#
#
# Epoch 4 in progress....
#
# Epoch : 4
#
# Average Train Loss : 0.006422297
# Train Accuracy :  77.6380%
#
# Average Test Loss : 0.006543947
# Test Accuracy :  76.9000%
#
#
# Epoch 5 in progress....
#
# Epoch : 5
#
# Average Train Loss : 0.005635202
# Train Accuracy :  80.4040%
#
# Average Test Loss : 0.006114770
# Test Accuracy :  78.4900%
#
#
# Epoch 6 in progress....
#
# Epoch : 6
#
# Average Train Loss : 0.005167686
# Train Accuracy :  82.1860%
#
# Average Test Loss : 0.006497714
# Test Accuracy :  77.3900%
#
#
# Epoch 7 in progress....
#
# Epoch : 7
#
# Average Train Loss : 0.004124561
# Train Accuracy :  86.0780%
#
# Average Test Loss : 0.004974619
# Test Accuracy :  83.1000%
#
#
# Epoch 8 in progress....
#
# Epoch : 8
#
# Average Train Loss : 0.003854249
# Train Accuracy :  86.9240%
#
# Average Test Loss : 0.004772680
# Test Accuracy :  83.4400%
#
#
# Epoch 9 in progress....
#
# Epoch : 9
#
# Average Train Loss : 0.003742925
# Train Accuracy :  87.3440%
#
# Average Test Loss : 0.004721385
# Test Accuracy :  84.0400%
#
#
# Epoch 10 in progress....
#
# Epoch : 10
#
# Average Train Loss : 0.003643132
# Train Accuracy :  87.4540%
#
# Average Test Loss : 0.004651512
# Test Accuracy :  84.0500%
#
#
# Epoch 11 in progress....
#
# Epoch : 11
#
# Average Train Loss : 0.003527651
# Train Accuracy :  88.0080%
#
# Average Test Loss : 0.004621835
# Test Accuracy :  84.1400%
#
#
# Epoch 12 in progress....
#
# Epoch : 12
#
# Average Train Loss : 0.003457954
# Train Accuracy :  88.3640%
#
# Average Test Loss : 0.004611522
# Test Accuracy :  84.4000%
#
#
# Epoch 13 in progress....
#
# Epoch : 13
#
# Average Train Loss : 0.003337083
# Train Accuracy :  88.6980%
#
# Average Test Loss : 0.004520489
# Test Accuracy :  84.4000%
#
#
# Epoch 14 in progress....
#
# Epoch : 14
#
# Average Train Loss : 0.003301058
# Train Accuracy :  88.7580%
#
# Average Test Loss : 0.004602014
# Test Accuracy :  84.1700%
#
#
# Epoch 15 in progress....
#
# Epoch : 15
#
# Average Train Loss : 0.003305591
# Train Accuracy :  88.7320%
#
# Average Test Loss : 0.004559833
# Test Accuracy :  84.2100%
#
#
# Epoch 16 in progress....
#
# Epoch : 16
#
# Average Train Loss : 0.003273640
# Train Accuracy :  88.9120%
#
# Average Test Loss : 0.004584153
# Test Accuracy :  84.3600%
#
#
# Epoch 17 in progress....
#
# Epoch : 17
#
# Average Train Loss : 0.003248220
# Train Accuracy :  89.1100%
#
# Average Test Loss : 0.004577214
# Test Accuracy :  84.2300%
#
#
# Epoch 18 in progress....
#
# Epoch : 18
#
# Average Train Loss : 0.003239880
# Train Accuracy :  89.1000%
#
# Average Test Loss : 0.004554564
# Test Accuracy :  84.4000%
#
#
# Epoch 19 in progress....
#
# Epoch : 19
#
# Average Train Loss : 0.003251619
# Train Accuracy :  89.0220%
#
# Average Test Loss : 0.004598397
# Test Accuracy :  84.3100%
#
#
# Epoch 20 in progress....
#
# Epoch : 20
#
# Average Train Loss : 0.003254891
# Train Accuracy :  89.0640%
#
# Average Test Loss : 0.004576906
# Test Accuracy :  84.4500%
#
#
# Epoch 21 in progress....
#
# Epoch : 21
#
# Average Train Loss : 0.003251570
# Train Accuracy :  88.9400%
#
# Average Test Loss : 0.004642512
# Test Accuracy :  84.3500%
#
#
# Epoch 22 in progress....
#
# Epoch : 22
#
# Average Train Loss : 0.003232711
# Train Accuracy :  89.0880%
#
# Average Test Loss : 0.004528689
# Test Accuracy :  84.6100%
#
#
# Epoch 23 in progress....
#
# Epoch : 23
#
# Average Train Loss : 0.003242894
# Train Accuracy :  88.9160%
#
# Average Test Loss : 0.004562312
# Test Accuracy :  84.1200%
#
#
# Epoch 24 in progress....
#
# Epoch : 24
#
# Average Train Loss : 0.003222630
# Train Accuracy :  89.2920%
#
# Average Test Loss : 0.004600038
# Test Accuracy :  84.1800%
#
#
# Epoch 25 in progress....
#
# Epoch : 25
#
# Average Train Loss : 0.003240529
# Train Accuracy :  89.0780%
#
# Average Test Loss : 0.004525820
# Test Accuracy :  84.3800%

# %% [markdown]
# ## Plotting the graph for the logged results

# %%
graphs = Graphs('Validation Loss', 'Validation Accuracy')

# %%
graphs.line_graph((15,15), test_losses, test_accuracies)

# %% [markdown]
# ## Plotting 25 Misclassified Predictions

# %%
graphs.image_graph(5, 5, wrong_pred_data['Predicted'], wrong_pred_data['Actual'], wrong_pred_data['Images'])
